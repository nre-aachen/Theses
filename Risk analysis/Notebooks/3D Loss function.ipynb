# %%
# %run '3DUncModel_Functions.ipynb'
# Out:
# /home/bl9/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/message.c:4294)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Theses/Risk analysis/Notebooks/3DUncModel_Functions.ipynb in <module>()
#       2 interp_data = gp.InterpolatorInput(geo_data,
#       3                                    u_grade = [3, 3],
# ----> 4                                    compile_theano=True)
#
# ~/gempy/gempy/DataManagement.py in __init__(self, geo_data, compile_theano, compute_all, u_grade, rescaling_factor, **kwargs)
# ...

# %%
# SETTING Z-UNCERTAINTIES FOR EACH LAYER TOP

z_sec_res_top = pymc.Normal('z_unc_sec_res', 0, 1./0.0001)
z_seal_top = pymc.Normal('z_unc_seal', 0, 1./0.0003)
z_res_top = pymc.Normal('z_unc_res', 0, 1./0.0005)
z_over_top = pymc.Normal('z_unc_over', 0, 1./0.0008)

# %%
iterations = 5
model2 = pymc.Model([model_unc_all, z_sec_res_top, z_seal_top, z_res_top, z_over_top])

# %%
M2 = pymc.MCMC(model2)
M2.sample(iter=iterations)

# %%
z_res_top =         res_unc_trace[3]
z_sec_res_top = sec_res_unc_trace[3]
z_seal_top =       seal_unc_trace[3]
z_over_top =       over_unc_trace[3]
