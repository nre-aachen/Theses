# %%
import sys
sys.path.append("/home/bl9/gempy/")
import gempy as gp

# %matplotlib inline
import pymc
import numpy as np
import math

#import geobayes_simple as gs
from IPython.core.display import Image

from pymc.Matplot import plot
from pymc import graph

from IPython.core.pylabtools import figsize
figsize(15, 6)

#import seaborn
#seaborn.set_context(font_scale=2)
#seaborn.set_style("white")

import scipy.optimize as sop
import scipy.stats as stats
from scipy.signal import argrelextrema

import matplotlib.mlab as mlab
from matplotlib import pyplot as plt

#import visualization_vtk as vv
# Out:
# /home/bl9/gempy/gempy/Visualization.py:15: UserWarning: Vtk package is not installed. No vtk visualization available.
#   warnings.warn('Vtk package is not installed. No vtk visualization available.')

# %%
# Importing the data from csv files and settign extent and resolution
geo_data = gp.create_data([0,2000,0,2000,-2000,0],[ 50,50,50],
                         path_f = "/home/bl9/gempy//input_data/FabLessPoints_Foliations.csv",
                         path_i = "/home/bl9/gempy//input_data/FabLessPoints_Points.csv")
geo_data.n_faults = 1

# %%
gp.set_data_series(geo_data, {"fault":'MainFault', 
                      "Rest":('Reservoir', 'Seal', 'NonReservoirDeep','SecondaryReservoir')},
                       order_series = ["fault",
                                       "Rest",
                                       ], verbose=0)

# %%
gp.data_to_pickle(geo_data, 'BasicFault')

# %%
# stdev for x,y,z interface coordinates
geo_data.interfaces['X_std'] = None
geo_data.interfaces['Y_std'] = None
geo_data.interfaces['Z_std'] = None
geo_data.interfaces['dist_type'] = "Normal" # should be initially None
geo_data.interfaces['X_dist'] = None
geo_data.interfaces['Y_dist'] = None
geo_data.interfaces['Z_dist'] = None

# %%
geo_data.interfaces.head()
# Out:
#         X       Y       Z  formation series  order_series  isFault X_std  \
# 0   800.0  1000.0 -1600.0  MainFault  fault             1     True  None
# 1  1200.0  1000.0  -400.0  MainFault  fault             1     True  None
# 2  1100.0  1000.0  -700.0  MainFault  fault             1     True  None
# 3   900.0  1000.0 -1300.0  MainFault  fault             1     True  None
# 4  1000.0  1000.0 -1000.0  MainFault  fault             1     True  None
#
#   Y_std Z_std dist_type X_dist Y_dist Z_dist
# 0  None  None    Normal   None   None   None
# 1  None  None    Normal   None   None   None
# 2  None  None    Normal   None   None   None
# 3  None  None    Normal   None   None   None
# 4  None  None    Normal   None   None   None

# %%
#geo_data.interfaces["Z_std"].iloc[0] = 500

# %%
interp_data = gp.InterpolatorInput(geo_data, 
                                   u_grade = [3, 3],
                                   compile_theano=True)
# Out:
# [2, 2]

# %%
#interp_copy = interp_data.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cc6f96938149> in <module>()
# ----> 1 interp_copy = interp_data.copy()
#
# AttributeError: 'InterpolatorInput' object has no attribute 'copy'

# %%
import copy
#copy.deepcopy?

# %%
sol = gp.compute_model(interp_data)
# Out:
# [3, 3]

# %%
sol.shape
# Out:
# (3, 125000)

# %%
gp.plot_section(geo_data, sol[0,:], 25)

# %%
interp_data.get_formation_number()
# Out:
# {'DefaultBasement': 0,
#  'MainFault': 1,
#  'NonReservoirDeep': 5,
#  'Reservoir': 2,
#  'Seal': 4,
#  'SecondaryReservoir': 3}

# %%
z_res_top = pymc.Normal('z_unc_res', 0, 1./0.001)

# %%
#a = interp_data.geo_data_res.interfaces[interp_data.geo_data_res.interfaces['formation'] == 'Seal']
#a['Z'] = z_res_top

# %%
#interp_data.geo_data_res.interfaces.ix[interp_data.geo_data_res.interfaces.formation=='Reservoir', 'Z'] += [z_res_top]

# %%
interp_data.geo_data_res.interfaces
# Out:
#            X         Y         Z           formation series  order_series  \
# 0   0.410356    0.5001  0.346254           MainFault  fault             1
# 1   0.512921    0.5001  0.653946           MainFault  fault             1
# 2   0.487279    0.5001  0.577023           MainFault  fault             1
# 3   0.435997    0.5001  0.423177           MainFault  fault             1
# 4   0.461638    0.5001    0.5001           MainFault  fault             1
# 5   0.282151    0.5001  0.512921           Reservoir   Rest             2
# 6   0.718049    0.5001  0.429587           Reservoir   Rest             2
# 7   0.692408    0.5001  0.423177           Reservoir   Rest             2
# 8   0.538562    0.5001  0.474459           Reservoir   Rest             2
# 9   0.359074    0.5001  0.487279           Reservoir   Rest             2
# 10  0.615485    0.5001  0.448818           Reservoir   Rest             2
# 11  0.653946    0.5001  0.435997           Reservoir   Rest             2
# 12  0.461638    0.2501  0.487279           Reservoir   Rest             2
# 13  0.461638  0.269331  0.474459           Reservoir   Rest             2
# 14  0.461638    0.7501  0.487279           Reservoir   Rest             2
# 15  0.461638  0.730869  0.474459           Reservoir   Rest             2
# 16  0.410356  0.705228  0.397536           Reservoir   Rest             2
# 17  0.410356  0.294972  0.397536           Reservoir   Rest             2
# 18    0.5001    0.5001  0.487279           Reservoir   Rest             2
# 19  0.435997    0.5001  0.589844  SecondaryReservoir   Rest             2
# 20  0.359074    0.5001  0.615485  SecondaryReservoir   Rest             2
# 21  0.538562    0.5001  0.602664  SecondaryReservoir   Rest             2
# 22  0.692408    0.5001  0.551382  SecondaryReservoir   Rest             2
# 23  0.615485    0.5001  0.577023  SecondaryReservoir   Rest             2
# 24  0.718049    0.5001  0.557792  SecondaryReservoir   Rest             2
# 25  0.359074    0.5001  0.589844                Seal   Rest             2
# 26  0.538562    0.5001  0.577023                Seal   Rest             2
# 27  0.615485    0.5001  0.551382                Seal   Rest             2
# 28  0.692408    0.5001  0.525741                Seal   Rest             2
# 29  0.718049    0.5001  0.532151                Seal   Rest             2
# 30  0.435997    0.5001  0.564203                Seal   Rest             2
# 31  0.359074    0.5001  0.410356    NonReservoirDeep   Rest             2
# 32  0.282151    0.5001  0.435997    NonReservoirDeep   Rest             2
# 33  0.718049    0.5001  0.352664    NonReservoirDeep   Rest             2
# 34  0.538562    0.5001  0.397536    NonReservoirDeep   Rest             2
# 35  0.615485    0.5001  0.371895    NonReservoirDeep   Rest             2
# 36  0.653946    0.5001  0.359074    NonReservoirDeep   Rest             2
# 37  0.461638    0.5001  0.423177    NonReservoirDeep   Rest             2
# 38  0.692408    0.5001  0.346254    NonReservoirDeep   Rest             2
#
#     isFault X_std Y_std Z_std dist_type X_dist Y_dist Z_dist  formation number
# 0      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 1      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 2      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 3      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 4      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 5     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 6     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 7     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 8     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 9     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 10    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 11    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 12    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 13    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 14    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 15    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 16    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 17    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 18    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 19    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 20    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 21    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 22    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 23    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 24    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 25    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 26    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 27    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 28    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 29    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 30    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 31    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 32    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 33    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 34    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 35    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 36    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 37    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 38    False   NaN   NaN   NaN    Normal   None   None   None                 5

# %%
interp_data.geo_data_res.interfaces
# Out:
#            X         Y         Z           formation series  order_series  \
# 0   0.410356    0.5001  0.346254           MainFault  fault             1
# 1   0.512921    0.5001  0.653946           MainFault  fault             1
# 2   0.487279    0.5001  0.577023           MainFault  fault             1
# 3   0.435997    0.5001  0.423177           MainFault  fault             1
# 4   0.461638    0.5001    0.5001           MainFault  fault             1
# 5   0.282151    0.5001  0.512921           Reservoir   Rest             2
# 6   0.718049    0.5001  0.429587           Reservoir   Rest             2
# 7   0.692408    0.5001  0.423177           Reservoir   Rest             2
# 8   0.538562    0.5001  0.474459           Reservoir   Rest             2
# 9   0.359074    0.5001  0.487279           Reservoir   Rest             2
# 10  0.615485    0.5001  0.448818           Reservoir   Rest             2
# 11  0.653946    0.5001  0.435997           Reservoir   Rest             2
# 12  0.461638    0.2501  0.487279           Reservoir   Rest             2
# 13  0.461638  0.269331  0.474459           Reservoir   Rest             2
# 14  0.461638    0.7501  0.487279           Reservoir   Rest             2
# 15  0.461638  0.730869  0.474459           Reservoir   Rest             2
# 16  0.410356  0.705228  0.397536           Reservoir   Rest             2
# 17  0.410356  0.294972  0.397536           Reservoir   Rest             2
# 18    0.5001    0.5001  0.487279           Reservoir   Rest             2
# 19  0.435997    0.5001  0.589844  SecondaryReservoir   Rest             2
# 20  0.359074    0.5001  0.615485  SecondaryReservoir   Rest             2
# 21  0.538562    0.5001  0.602664  SecondaryReservoir   Rest             2
# 22  0.692408    0.5001  0.551382  SecondaryReservoir   Rest             2
# 23  0.615485    0.5001  0.577023  SecondaryReservoir   Rest             2
# 24  0.718049    0.5001  0.557792  SecondaryReservoir   Rest             2
# 25  0.359074    0.5001  0.589844                Seal   Rest             2
# 26  0.538562    0.5001  0.577023                Seal   Rest             2
# 27  0.615485    0.5001  0.551382                Seal   Rest             2
# 28  0.692408    0.5001  0.525741                Seal   Rest             2
# 29  0.718049    0.5001  0.532151                Seal   Rest             2
# 30  0.435997    0.5001  0.564203                Seal   Rest             2
# 31  0.359074    0.5001  0.410356    NonReservoirDeep   Rest             2
# 32  0.282151    0.5001  0.435997    NonReservoirDeep   Rest             2
# 33  0.718049    0.5001  0.352664    NonReservoirDeep   Rest             2
# 34  0.538562    0.5001  0.397536    NonReservoirDeep   Rest             2
# 35  0.615485    0.5001  0.371895    NonReservoirDeep   Rest             2
# 36  0.653946    0.5001  0.359074    NonReservoirDeep   Rest             2
# 37  0.461638    0.5001  0.423177    NonReservoirDeep   Rest             2
# 38  0.692408    0.5001  0.346254    NonReservoirDeep   Rest             2
#
#     isFault X_std Y_std Z_std dist_type X_dist Y_dist Z_dist  formation number
# 0      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 1      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 2      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 3      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 4      True   NaN   NaN   NaN    Normal   None   None   None                 1
# 5     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 6     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 7     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 8     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 9     False   NaN   NaN   NaN    Normal   None   None   None                 2
# 10    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 11    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 12    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 13    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 14    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 15    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 16    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 17    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 18    False   NaN   NaN   NaN    Normal   None   None   None                 2
# 19    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 20    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 21    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 22    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 23    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 24    False   NaN   NaN   NaN    Normal   None   None   None                 3
# 25    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 26    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 27    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 28    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 29    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 30    False   NaN   NaN   NaN    Normal   None   None   None                 4
# 31    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 32    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 33    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 34    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 35    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 36    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 37    False   NaN   NaN   NaN    Normal   None   None   None                 5
# 38    False   NaN   NaN   NaN    Normal   None   None   None                 5

# %%
 sys.setrecursionlimit(10000)

# %%
@pymc.deterministic
def z_interp(input_ = interp_data, z_unc = z_res_top): #b = interp_fixed
    #change = input_.geo_data_res.interfaces.ix[input_.geo_data_res.interfaces.formation=='Reservoir', 'Z'] + [z_unc]
    print(z_unc)
    #a = input_.geo_data_res.interfaces[input_.geo_data_res.interfaces['formation'] == 'Reservoir']
    #print(a['Z'])
    #a['Z'] += z_unc
    #b = input_
    b = copy.deepcopy(input_)#.geo_data_res.interfaces.copy()
    print(b.geo_data_res.interfaces[b.geo_data_res.interfaces['formation'] == 'Reservoir']['Z'])
    #b.geo_data_res.interfaces[b.geo_data_res.interfaces['formation'] == 'Reservoir']['Z'] += [z_unc]
    b.geo_data_res.interfaces.ix[b.geo_data_res.interfaces['formation'] == 'Reservoir','Z'] += [z_unc]
    #print(a['Z'])
    #print(a['Z'])
    #b = input_.geo_data_res.interfaces[input_.geo_data_res.interfaces['formation'] == 'Reservoir', 'Z'] + [z_unc]
    #input_.geo_data_res.interfaces.ix[input_.geo_data_res.interfaces.formation=='Reservoir', 'Z'] += [z_unc]
    #print(a['Z'])
    print(b.geo_data_res.interfaces[b.geo_data_res.interfaces['formation'] == 'Reservoir']['Z'])
    return b

@pymc.deterministic
def z_model(interp = z_interp):
    sol = gp.compute_model(interp)
    gp.plot_section(geo_data, sol[0,:], 25)
    return sol
# Out:
# -0.0036341780687680816
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.509286
# 6     0.425953
# 7     0.419543
# 8     0.470825
# 9     0.483645
# 10    0.445184
# 11    0.432363
# 12    0.483645
# 13    0.470825
# 14    0.483645
# 15    0.470825
# 16    0.393902
# 17    0.393902
# 18    0.483645
# Name: Z, dtype: object
# [3, 3]
# /home/bl9/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   if sys.path[0] == '':

# %%
geo_data_res.interfaces
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-60f4f250d07f> in <module>()
# ----> 1 geo_data_res.interfaces
#
# NameError: name 'geo_data_res' is not defined

# %%
iterations = 10

# %%
# set model
model = pymc.Model([z_interp, z_model, z_res_top])

# %%
M = pymc.MCMC(model)
M.sample(iter=iterations)
# Out:
# 0.017199744791159145
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5      0.53012
# 6     0.446787
# 7     0.440377
# 8     0.491659
# 9     0.504479
# 10    0.466018
# 11    0.453197
# 12    0.504479
# 13    0.491659
# 14    0.504479
# 15    0.491659
# 16    0.414736
# 17    0.414736
# 18    0.504479
# Name: Z, dtype: object
# [3, 3]
# /home/bl9/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   if sys.path[0] == '':
#  [-------          20%                  ] 2 of 10 complete in 37.8 sec0.030506631346989367
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.543427
# 6     0.460094
# 7     0.453684
# 8     0.504966
# 9     0.517786
# 10    0.479325
# 11    0.466504
# 12    0.517786
# 13    0.504966
# 14    0.517786
# 15    0.504966
# 16    0.428043
# 17    0.428043
# 18    0.517786
# Name: Z, dtype: object
# [3, 3]
#  [-----------      30%                  ] 3 of 10 complete in 77.3 sec-0.043224352047186894
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.469696
# 6     0.386363
# 7     0.379953
# 8     0.431235
# 9     0.444055
# 10    0.405594
# 11    0.392773
# 12    0.444055
# 13    0.431235
# 14    0.444055
# 15    0.431235
# 16    0.354312
# 17    0.354312
# 18    0.444055
# Name: Z, dtype: object
# [3, 3]
#  [---------------  40%                  ] 4 of 10 complete in 111.4 sec0.022358973868625388
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.535279
# 6     0.451946
# 7     0.445536
# 8     0.496818
# 9     0.509638
# 10    0.471177
# 11    0.458356
# 12    0.509638
# 13    0.496818
# 14    0.509638
# 15    0.496818
# 16    0.419895
# 17    0.419895
# 18    0.509638
# Name: Z, dtype: object
# [3, 3]
#  [-----------------50%                  ] 5 of 10 complete in 148.1 sec-0.00865177176924869
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.504269
# 6     0.420935
# 7     0.414525
# 8     0.465807
# 9     0.478628
# 10    0.440166
# 11    0.427346
# 12    0.478628
# 13    0.465807
# 14    0.478628
# 15    0.465807
# 16    0.388884
# 17    0.388884
# 18    0.478628
# Name: Z, dtype: object
# [3, 3]
#  [-----------------60%--                ] 6 of 10 complete in 185.6 sec-0.05210885456262843
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.460812
# 6     0.377478
# 7     0.371068
# 8      0.42235
# 9     0.435171
# 10    0.396709
# 11    0.383889
# 12    0.435171
# 13     0.42235
# 14    0.435171
# 15     0.42235
# 16    0.345427
# 17    0.345427
# 18    0.435171
# Name: Z, dtype: object
# [3, 3]
#  [-----------------70%------            ] 7 of 10 complete in 216.1 sec-0.0087925862124494
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.504128
# 6     0.420795
# 7     0.414384
# 8     0.465666
# 9     0.478487
# 10    0.440025
# 11    0.427205
# 12    0.478487
# 13    0.465666
# 14    0.478487
# 15    0.465666
# 16    0.388743
# 17    0.388743
# 18    0.478487
# Name: Z, dtype: object
# [3, 3]
#  [-----------------80%----------        ] 8 of 10 complete in 256.7 sec-0.03694677309293516
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.475974
# 6      0.39264
# 7      0.38623
# 8     0.437512
# 9     0.450333
# 10    0.411871
# 11    0.399051
# 12    0.450333
# 13    0.437512
# 14    0.450333
# 15    0.437512
# 16    0.360589
# 17    0.360589
# 18    0.450333
# Name: Z, dtype: object
# [3, 3]
#  [-----------------90%--------------    ] 9 of 10 complete in 285.9 sec0.012155568143769339
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.525076
# 6     0.441743
# 7     0.435332
# 8     0.486615
# 9     0.499435
# 10    0.460974
# 11    0.448153
# 12    0.499435
# 13    0.486615
# 14    0.499435
# 15    0.486615
# 16    0.409691
# 17    0.409691
# 18    0.499435
# Name: Z, dtype: object
# [3, 3]
#  [-----------------100%-----------------] 10 of 10 complete in 325.4 sec-0.004019368862547451
# 5     0.512921
# 6     0.429587
# 7     0.423177
# 8     0.474459
# 9     0.487279
# 10    0.448818
# 11    0.435997
# 12    0.487279
# 13    0.474459
# 14    0.487279
# 15    0.474459
# 16    0.397536
# 17    0.397536
# 18    0.487279
# Name: Z, dtype: object
# 5     0.508901
# 6     0.425568
# 7     0.419158
# 8      0.47044
# 9      0.48326
# 10    0.444799
# 11    0.431978
# 12     0.48326
# 13     0.47044
# 14     0.48326
# 15     0.47044
# 16    0.393517
# 17    0.393517
# 18     0.48326
# Name: Z, dtype: object
# [3, 3]
#  [------------------110%-------------------] 11 of 10 complete in 355.1 sec

# %%
bla = M.trace('z_unc_res')[:]
ble = M.trace('z_interp')[:]
bli = M.trace('z_model')[:]
bla.shape
# Out:
# (10,)

# %%
for j in range(iterations):
    plt.figure()
    plt.title('Change in res_top: %s' % bla[j])
    print(bla[j])
    gp.plot_section(geo_data, bli[j,0], 25)
# Out:
# 0.0171997447912
# 0.030506631347
# -0.0432243520472
# 0.0223589738686
# -0.00865177176925
# -0.0521088545626
# -0.00879258621245
# -0.0369467730929
# 0.0121555681438
# -0.00401936886255

# %%
plt.plot(bla)

# %%
interp_data.geo_data_res.interfaces??

# %%
ble[0].geo_data_res.interfaces

# %%
#i,s = gp.get_surface(sol[1, :], interp_data, 2)
#plt.plot(i[:,2])
gp.surface??
